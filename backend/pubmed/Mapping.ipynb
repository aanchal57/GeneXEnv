# %%
import pandas as pd
import csv

# %%
df=pd.read_csv('/content/geneextractiondata-snpedia - cleaned-data.csv')

# %%
len(df['genes'])
file = open('Gene_env.csv', 'w', newline ='')
 
with file:
    # identifying header 
    header = ['Gene', 'Env']
    writer = csv.DictWriter(file, fieldnames = header)
     
    # writing data row-wise into the csv file
    writer.writeheader()

# %%
lis=['SNP','variant','interaction','diet','physical activity','excercise','alcohol','tobacco','cigarette']
filename = open('Gene_env.csv', 'a+', newline ='')
write = csv.writer(filename)
for i in range(0,len(lis)):
  for j in range(0,len(df['genes'])):
      write.writerow([df['genes'][j],lis[i]])

# %%
df_new=pd.read_csv('/content/Gene_env.csv')
df_new
# Out:
#           Gene        Env
# 0       A4GALT        SNP
# 1        AANAT        SNP
# 2         AARS        SNP
# 3        AARS2        SNP
# 4        ABCA1        SNP
# ...        ...        ...
# 19119  SLC4A11  cigarette
# 19120   SLC4A5  cigarette
# 19121   SLC5A2  cigarette
# 19122   SLC5A5  cigarette
# 19123   SLC6A1  cigarette
#
# [19124 rows x 2 columns]
